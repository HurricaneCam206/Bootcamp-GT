# %% [markdown]
# <a href="https://colab.research.google.com/github/HurricaneCam206/Bootcamp-GT/blob/main/Module%200/Topics%204/cse6040fa20_20200903_torch_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
print("* Python version:", sys.version)
# Out:
# * Python version: 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]

# %%
import torch
print("* PyTorch version:", torch.__version__)
# Out:
# * PyTorch version: 2.9.0+cu126

# %%
n = 1000
A_torch = torch.rand((n, n))

# %%
B_torch = torch.rand((n, n))
C_torch = A_torch @ B_torch

# %%
# %timeit A_torch @ B_torch
# Out:
# 33.8 ms ± 12.1 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
A_gpu = A_torch.to('cuda')
B_gpu = B_torch.to('cuda')
C_gpu = A_gpu @ B_gpu

# %%
# %timeit A_gpu @ B_gpu
# Out:
# 522 µs ± 18.1 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# Error: maximum absolute difference of any entry
(C_gpu.to('cpu') - C_torch).abs().max()
# Out:
# tensor(0.0001)

# %%
# Aside: Cost of data transfer
# %timeit A_torch.to('cuda')
# Out:
# 892 µs ± 26.8 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
